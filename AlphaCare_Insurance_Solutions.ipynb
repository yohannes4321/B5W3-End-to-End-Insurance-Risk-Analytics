# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('..\data\MachineLearningRating_v3.txt',sep='|')
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Hp\AppData\Local\Temp\ipykernel_22612\287621043.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df=pd.read_csv('..\data\MachineLearningRating_v3.txt',sep='|')
# C:\Users\Hp\AppData\Local\Temp\ipykernel_22612\287621043.py:1: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('..\data\MachineLearningRating_v3.txt',sep='|')
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000098 entries, 0 to 1000097
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   UnderwrittenCoverID       1000098 non-null  int64
#  1   PolicyID                  1000098 non-null  int64
#  2   TransactionMonth          1000098 non-null  object
#  3   IsVATRegistered           1000098 non-null  bool
#  4   Citizenship               1000098 non-null  object
#  5   LegalType                 1000098 non-null  object
#  6   Title                     1000098 non-null  object
#  7   Language                  1000098 non-null  object
#  8   Bank                      854137 non-null   object
#  9   AccountType               959866 non-null   object
#  10  MaritalStatus             991839 non-null   object
#  11  Gender                    990562 non-null   object
#  12  Country                   1000098 non-null  object
# ...

# %% [markdown]
# Cheack null value and fillna and dropna values based on wheater they are important or not

# %%
df.isna().sum()
# Out:
# UnderwrittenCoverID               0
# PolicyID                          0
# TransactionMonth                  0
# IsVATRegistered                   0
# Citizenship                       0
# LegalType                         0
# Title                             0
# Language                          0
# Bank                         145961
# AccountType                   40232
# MaritalStatus                  8259
# Gender                         9536
# Country                           0
# Province                          0
# PostalCode                        0
# MainCrestaZone                    0
# SubCrestaZone                     0
# ItemType                          0
# mmcode                          552
# VehicleType                     552
# RegistrationYear                  0
# make                            552
# Model                           552
# Cylinders                       552
# cubiccapacity                   552
# kilowatts                       552
# ...

# %%
df.dtypes
# Out:
# UnderwrittenCoverID           int64
# PolicyID                      int64
# TransactionMonth             object
# IsVATRegistered                bool
# Citizenship                  object
# LegalType                    object
# Title                        object
# Language                     object
# Bank                         object
# AccountType                  object
# MaritalStatus                object
# Gender                       object
# Country                      object
# Province                     object
# PostalCode                    int64
# MainCrestaZone               object
# SubCrestaZone                object
# ItemType                     object
# mmcode                      float64
# VehicleType                  object
# RegistrationYear              int64
# make                         object
# Model                        object
# Cylinders                   float64
# cubiccapacity               float64
# kilowatts                   float64
# ...

# %%
df['Gender'].fillna(df['Gender'].mode())
df['VehicleType'].fillna(df['VehicleType'].mean())

# %%
df.dropna()

# %%
df.nunique()
# Out:
# UnderwrittenCoverID         116532
# PolicyID                      7000
# TransactionMonth                23
# IsVATRegistered                  2
# Citizenship                      4
# LegalType                        6
# Title                            5
# Language                         1
# Bank                            11
# AccountType                      3
# MaritalStatus                    3
# Gender                           3
# Country                          1
# Province                         9
# PostalCode                     888
# MainCrestaZone                  16
# SubCrestaZone                   45
# ItemType                         1
# mmcode                         427
# VehicleType                      5
# RegistrationYear                25
# make                            46
# Model                          411
# Cylinders                        7
# cubiccapacity                  122
# kilowatts                       82
# bodytype                        13
# ...

# %%
df_clean = df[(df['TotalPremium'] > 0) & (df['TotalPremium'].notna()) & (df['TotalClaims'].notna())]
df_clean['LossRatio'] = df_clean['TotalClaims'] / df_clean['TotalPremium']
data = ['Province', 'VehicleType', 'Gender']
plt.figure(figsize=(12, 10))

for idx, d in enumerate(data, 1):
    plt.subplot(len(data), 1, idx)
    grouped = df_clean.groupby(d)['LossRatio'].mean().sort_values(ascending=False)
    
    sns.barplot(x=grouped.index, y=grouped.values, palette='viridis')
    plt.title(f'Average Loss Ratio by {d}')
    plt.xlabel(d)
    plt.ylabel('Average Loss Ratio')
    plt.xticks(rotation=45)
    plt.tight_layout()

plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_24356\168596897.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['LossRatio'] = df_clean['TotalClaims'] / df_clean['TotalPremium']
# C:\Users\Hp\AppData\Local\Temp\ipykernel_24356\168596897.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=grouped.index, y=grouped.values, palette='viridis')
# C:\Users\Hp\AppData\Local\Temp\ipykernel_24356\168596897.py:10: FutureWarning:
#
# ...

# %%
df_data=df[(df['TotalPremium'] >0) & (df['TotalPremium'].notna()) & (df['TotalClaims']).notna()]
df['loss_data']=df_data['TotalClaims']/df_data['TotalPremium']
plt.figure(figsize=(13,8))
data = ['Province', 'VehicleType', 'Gender']
for idx,va in enumerate(data,1):
    
    plt.subplot(len(data),1,idx)
    g=df_data.groupby(va)['loss_data'].mean().sort_values(ascending=False)
    sns.barplot(x=g.index,y=g.values)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.ylabel('loss_data')
    plt.xlabel(va)
plt.show()
